# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Load the https://www.residentadvisor.net/events page in your browser.
test_url = 'https://www.residentadvisor.net/events'

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %% [markdown]
# ### Write a function to parse the page into soup

# %%
def get_soup(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    return soup

# %%
test_soup = get_soup(test_url)
test_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en,ja,es">
# <head id="_x1">
# <script>
#             if (typeof dataLayer === 'undefined') {
#                 dataLayer = []
#             }
#         </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-940832047"></script>
# <script>
#             window.dataLayer = window.dataLayer || [];
#
#             function gtag() { dataLayer.push(arguments); }
#             gtag('js', new Date());
#
#             gtag('config', 'AW-940832047');
#         </script>
# <script>
#             (function (w, d, s, l, i) {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#             })(window, document, 'script', 'dataLayer', 'GTM-M269WMP');
#         </script>
# <title>
# 	RA: Events in Toronto, Canada
# </title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en,ja,es" http-equiv="content-language"/><meta content="RA: Resident Advisor" name="Description"/><meta content="RA, residentadvisor, resident, advisor, music, ra, events, in, toronto, canada" name="Keywords"/><meta content="Resident Advisor" name="Author"/><meta content="Resident Advisor" property="og:site_name"/><meta content="712773712080127" property="fb:app_id"/><link href="/bundles/default-css?v=nA9uavMPeFtRavUj5m2TICqAtGhp7tbC5z-iw5vW6k81" rel="stylesheet"/>
# <meta content="app-id=981952703, app-argument=ra-guide://search" name="apple-itunes-app"/><link href="/bundles/cat-listings-css?v=f4eB862zmilD4dOWmR7ebuJfszYQdGcmWXBVo2GCefI1" rel="stylesheet"/>
# <link href="/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/><link color="#000000" href="/images/ra_icon.svg" rel="mask-icon"/><script src="/bundles/default-js?v=ojfhnSS3vQR_E4mHHYGVG8VBKABXIiKyvhub_-LVawo1"></script>
# <script>
# 	    googletag.cmd.push(function () { googletag.pubads().setTargeting("Page", "/events/ca/toronto").setTargeting("Category", "Listings").setTargeting("Section", "Events").setTargeting("Content", "EventsHome").setTargeting("Country", "CA").setTargeting("Area", "Toronto"); });
#          console.info('Interested in our code? Join us and help write it - https://www.residentadvisor.net/about/jobs');
#     </script>
# <script>
#             const widthTest = false;
#         if (window.screen.availWidth < 663 && window.screen.width < window.screen.height && !widthTest) {
#             document.write('<meta name="viewport" content="width=328">');
#         } else {
#             document.write('<meta name="viewport" content="width=device-width, initial-scale=1">');
#         }
#     </script>
# <script src="/js/dist/ReactLibs.bundle.js?637343601119512097"></script></head>
# <body id="body">
# <input id="user-id" name="user-id" type="hidden" value="0"/>
# <input id="see-ngc" name="see-ngc" type="hidden" value="false"/>
# <a name="top"></a>
# <header id="header">
# <div class="pnlLeaderWrapper">
# <div id="pnlLeader">
# <aside class="div-gpt-ad-1452773484957-6 leader"><div class="ad" id="div-gpt-ad-1452773484957-6"></div></aside>
# </div>
# </div>
# <nav class="clearfix" id="user">
# <ul style="-moz-user-select: -moz-none; -khtml-user-select: none; -webkit-user-select: none;">
# <li class="but dark arrow-down" id="basket">
# Basket
# <div class="count basket" style="display:none;"><span></span></div>
# </li>
# <li class="but subscribe desktop-only desktop-wide-only" data-use-same-tab="true" id="nav-link">
# <a ga-event-action="subscribe-nav-link" ga-event-category="subscriptions" ga-on="click" href="/subscribe">
# <span>Subscribe</span>
# </a>
# </li>
# <li class="but arrow-down temp login" id="profile">Login / Register
# </li>
# </ul>
# </nav>
# <ul class="bbox panel" id="profile-panel">
# <li><a href="https://www.residentadvisor.net/login">Login</a></li>
# <li><a href="https://www.residentadvisor.net/register">Register</a></li>
# </ul>
# <div class="bbox panel bbox generic clearfix" id="basket-panel">
# <div class="items"></div><div class="basket-but but myra"></div>
# </div>
# <div class="notificationPanel bbox clearfix events col3" id="notificationPanel"></div>
# <div class="null" id="navContainer">
# <div id="navbar">
# <div id="logo"><a class="icon" href="/">Resident Advisor</a></div>
# <div class="modal-full-screen" id="search-bar">
# <span class="modal-close">×</span>
# <div class="modal-body" id="search-bar-internal">
# <span class="f24 mobile-only search-header">Search</span>
# <div id="search-box-div">
# <input id="search-box" placeholder="Artists, Clubs, Promoters, Cities" type="text"/>
# </div>
# <div class="but large" id="search-button">
# <a id="search" title="Search">Submit</a>
# </div>
# <div class="grey pt16 search-helper" style="display: none;">Did you mean</div>
# </div>
# </div>
# <nav class="modal-full-screen" id="nav" role="navigation">
# <div class="modal-close">×</div>
# <ul class="modal-body open" data-display="0" id="links">
# <li class="mobile-only tablet-off">
# <div id="logo-modal-nav">
# <a class="icon" ga-event-action="RA-Logo" ga-event-category="nav" ga-on="click" href="/">Resident Advisor</a>
# </div>
# </li>
# <li id="mMagazine">
# <span>
# Magazine</span>
# <ul>
# <li id="mNews"><a ga-event-action="News" ga-event-category="nav" ga-on="click" href="/news">
# News</a></li>
# <li id="mReviews"><a ga-event-action="Reviews" ga-event-category="nav" ga-on="click" href="/reviews.aspx">
# Reviews</a></li>
# <li id="mFeatures"><a ga-event-action="Features" ga-event-category="nav" ga-on="click" href="/features.aspx">
# Features</a></li>
# <li id="mFilms"><a ga-event-action="Videos" ga-event-category="nav" ga-on="click" href="/videos">
# Videos</a></li>
# </ul>
# </li>
# <li data-selected="1" id="mListings">
# <span>
# Listings</span>
# <ul>
# <li data-selected="1" id="mEvents"><a ga-event-action="Events" ga-event-category="nav" ga-on="click" href="/events">
# Events</a></li>
# <li id="mClubs"><a ga-event-action="Clubs" ga-event-category="nav" ga-on="click" href="/clubs.aspx">
# Clubs</a></li>
# <li id="mFestivals"><a ga-event-action="Festivals" ga-event-category="nav" ga-on="click" href="/festivals.aspx">
# Festivals</a></li>
# <li id="mStreamland"><a ga-event-action="Streamland" ga-event-category="nav" ga-on="click" href="/events/streamland">
# Streamland</a></li>
# </ul>
# </li>
# <li id="mMusic">
# <span>
# Music</span>
# <ul>
# <li id="mDjpages"><a ga-event-action="Artists" ga-event-category="nav" ga-on="click" href="/dj.aspx">
# Artists</a></li>
# <li id="mMixOfTheDay"><a ga-event-action="Mix of the day" ga-event-category="nav" ga-on="click" href="/news/mix-of-the-day/2020/8">
# Mix of the day</a></li>
# <li id="mCharts"><a ga-event-action="DJ Charts" ga-event-category="nav" ga-on="click" href="/dj-charts.aspx">
# DJ Charts</a></li>
# <li id="mPodcast"><a ga-event-action="Podcasts" ga-event-category="nav" ga-on="click" href="/podcast.aspx">
# Podcasts</a></li>
# </ul>
# </li>
# <li data-url="https://search.residentadvisor.net/" id="mSearch">
# <a ga-event-action="reveal-desktop" ga-event-category="search" ga-on="click" href="#">
# Search</a>
# </li>
# </ul>
# </nav>
# <div ga-event-action="burger" ga-event-category="nav" ga-on="click" id="but-links">
# <div class="icon"></div>
# </div>
# <div ga-event-action="mobile-reveal" ga-event-category="search" ga-on="click" id="but-search">
# <div class="icon"></div>
# </div>
# </div>
# <div class="add-space" id="sectionHead">
# <h1>Events</h1>
# </div>
# <link href="/bundles/autocomplete-css?v=hX3EIxBPUes4W-JFrW9vc2V9eyRDs1p9rgi0LcnlXug1" rel="stylesheet"/>
# <script src="/bundles/autocomplete?v=SCtA5z9vnBIQK6ZI-wtyD14u0Lv-S6kQhwTW5lgrMYQ1"></script>
# <script src="/bundles/analytics-js?v=pUK2ZxBTfTo6P0-8Xh1_QmhiGk4YBwWiTKDOFLGXwbg1"></script>
# </div>
# <section class="clearfix" id="subnav">
# <ul>
# <li class="on" id="subnav-all"><a href="/events">All</a></li><li id="subnav-new"><a href="/events/new">New</a></li><li id="subnav-for-you"><a href="/events/favourites">For You</a></li><li id="subnav-promoters"><a href="/promoters.aspx">Promoters</a></li><li id="subnav-submit-an-event"><a href="/submit-event.aspx">Submit an event</a></li>
# </ul>
# </section>
# </header>
# <form action="./events" id="Form1" method="post">
# <div class="aspNetHidden">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="4OicUgY2vo6F447D+38Lbe9naTP+Sy1IqLuWh1vnhuB7cC5br2wpdTT6yxuwQfDe9s8M032oc3iy4e2S47x0ZmSS7/w="/>
# </div>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="ADA4D364"/>
# </div>
# <main>
# <script src="/bundles/sticky-js?v=v676-NN9nrtj1Xpc3-lLALpuQvn14WLF-0HBUTbxEIQ1"></script>
# <script>
#     $(document).ready(function() {
#         $('.slide')
#         .scrollSnap({
#             page: 'eventshome'
#         });
#     })
#     </script>
# <ul class="content-list events-border">
# <li class="alt nobreak">
# <section class="content clearfix">
# <h1 class="listing-heading heading">Popular events in Toronto</h1>
# <div class="strip slide small" data-type="events" id="events-listing">
# <ul class="list small clearfix popular" style="padding: 0;">
# <li class="">
# <article class="highlight-top">
# <p>Sat, 5 Sep 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1396872"><img class="nohide" src="/images/events/flyer/2020/9/ca-0905-1396872-list.jpg"/></a>
# <p class="counter nohide">
# <span>7</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1396872">
# <h1>
# Electric Island Labour Day 1
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=182456">Ontario Place West Island</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sun, 6 Sep 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1396876"><img class="nohide" src="/images/events/flyer/2020/9/ca-0906-1396876-list.jpg"/></a>
# <p class="counter nohide">
# <span>5</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1396876">
# <h1>
# Electric Island Labour Day 2
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=182456">Ontario Place West Island</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 12 Sep 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1395192"><img class="nohide" src="/images/events/flyer/2020/3/ca-0314-1395192-list.jpg"/></a>
# <p class="counter nohide">
# <span>8</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1395192">
# <h1>
# Disco &amp; House Music Tribute Party with Crystal Waters
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=6144">Revival</a>
# </p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a></a>
# </div>
# <script>
#                             googleAnalytics.sendEventDataOnLoad('events-page', 'popular-events-loaded');
#                        </script>
# </section>
# <section class="iOSOnly content">
# <ul class="phones">
# <li class="f12 pb4 grey">Want RA listings on your mobile?</li>
# <li>
# <div class="but"><a href="https://itunes.apple.com/app/apple-store/id981952703?mt=8">Download the RA Guide</a></div>
# </li>
# </ul>
# </section>
# <div class="banner clearfix">
# <div id="pnlECTOSlot1" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-0"></div>
# </div>
# </div>
# </li>
# <li class="clearfix pt1">
# <div class="page-items content" id="previous-next">
# <ul>
# <li class="but arrow-left left" id="liPrevious">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/ca/toronto/week/2020-08-23">Previous </a>
# </li><li class="but arrow-right right" id="liNext">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/ca/toronto/week/2020-09-06">Next </a>
# </li>
# </ul>
# </div>
# <div class="content clearfix">
# <div class="plus8">
# <div>
# <script src="/bundles/area-country-date-filter-js?v=Q02f5CsIXWPDeOtgJVocYJrwjcQrf96m1qneHFerLLA1"></script>
# <ul class="clearfix classic" data-enableevent="True" id="ulButtons">
# <li class="but arrow-down right" id="liCountry">
# <input id="hdnCountryId" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnCountryId" type="hidden" value="7"/>
# <span>CA</span><input id="country-name" type="hidden" value="Canada"/><ul class="links" style="display: none;"><li class="selected" data-id="7"><a href="/events">Canada</a></li><li data-id="15"><a href="/events">France</a></li><li data-id="12"><a href="/events">Germany</a></li><li data-id="20"><a href="/events">Italy</a></li><li data-id="6"><a href="/events">Netherlands</a></li><li data-id="5"><a href="/events">Spain</a></li><li data-id="3"><a href="/events">United Kingdom</a></li><li data-id="2"><a href="/events">United States of America</a></li><li data-id="0"><a href="/events">------------</a></li><li data-id="99"><a href="/events">Albania</a></li><li data-id="125"><a href="/events">Algeria</a></li><li data-id="113"><a href="/events">Andorra</a></li><li data-id="127"><a href="/events">Angola</a></li><li data-id="140"><a href="/events">Antigua and Barbuda</a></li><li data-id="16"><a href="/events">Argentina</a></li><li data-id="106"><a href="/events">Armenia</a></li><li data-id="1"><a href="/events">Australia</a></li><li data-id="57"><a href="/events">Austria</a></li><li data-id="108"><a href="/events">Azerbaijan</a></li><li data-id="117"><a href="/events">Bahamas</a></li><li data-id="80"><a href="/events">Bahrain</a></li><li data-id="107"><a href="/events">Bangladesh</a></li><li data-id="73"><a href="/events">Barbados</a></li><li data-id="76"><a href="/events">Belarus</a></li><li data-id="29"><a href="/events">Belgium</a></li><li data-id="34"><a href="/events">Belize</a></li><li data-id="141"><a href="/events">Benin</a></li><li data-id="126"><a href="/events">Bermuda</a></li><li data-id="142"><a href="/events">Bhutan</a></li><li data-id="85"><a href="/events">Bolivia</a></li><li data-id="74"><a href="/events">Bosnia and Herzegovina</a></li><li data-id="143"><a href="/events">Botswana</a></li><li data-id="28"><a href="/events">Brazil</a></li><li data-id="47"><a href="/events">Bulgaria</a></li><li data-id="144"><a href="/events">Burkina Faso</a></li><li data-id="110"><a href="/events">Cambodia</a></li><li data-id="145"><a href="/events">Cameroon</a></li><li class="selected" data-id="7"><a href="/events">Canada</a></li><li data-id="92"><a href="/events">Cayman Islands</a></li><li data-id="25"><a href="/events">Chile</a></li><li data-id="30"><a href="/events">China</a></li><li data-id="59"><a href="/events">Colombia</a></li><li data-id="10"><a href="/events">Costa Rica</a></li><li data-id="146"><a href="/events">Cote d'Ivoire</a></li><li data-id="46"><a href="/events">Croatia</a></li><li data-id="102"><a href="/events">Cuba</a></li><li data-id="129"><a href="/events">Curacao</a></li><li data-id="82"><a href="/events">Cyprus</a></li><li data-id="49"><a href="/events">Czech Republic</a></li><li data-id="147"><a href="/events">Democratic Republic of the Congo</a></li><li data-id="51"><a href="/events">Denmark</a></li><li data-id="66"><a href="/events">Dominican Republic</a></li><li data-id="72"><a href="/events">Ecuador</a></li><li data-id="48"><a href="/events">Egypt</a></li><li data-id="54"><a href="/events">El Salvador</a></li><li data-id="71"><a href="/events">Estonia</a></li><li data-id="160"><a href="/events">Ethiopia</a></li><li data-id="158"><a href="/events">Fiji</a></li><li data-id="41"><a href="/events">Finland</a></li><li data-id="15"><a href="/events">France</a></li><li data-id="148"><a href="/events">Gambia</a></li><li data-id="75"><a href="/events">Georgia</a></li><li data-id="12"><a href="/events">Germany</a></li><li data-id="149"><a href="/events">Ghana</a></li><li data-id="103"><a href="/events">Gibraltar</a></li><li data-id="13"><a href="/events">Greece</a></li><li data-id="116"><a href="/events">Guam</a></li><li data-id="87"><a href="/events">Guatemala</a></li><li data-id="63"><a href="/events">Honduras</a></li><li data-id="39"><a href="/events">Hungary</a></li><li data-id="86"><a href="/events">Iceland</a></li><li data-id="58"><a href="/events">India</a></li><li data-id="37"><a href="/events">Indonesia</a></li ...
# </li>
# <li class="but arrow-down right" id="liArea">
# <input id="btnArea" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$btnArea" style="display:none;" type="submit" value="">
# <input id="hdnAreaId" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnAreaId" type="hidden" value="28"/>
# <span>Toronto</span><ul class="links" style="display: none;"><li class="parent" data-id="230"><a href="/events">Atlantic Provinces</a></li><li class="parent" data-id="137"><a href="/events">Calgary</a></li><li class="parent" data-id="54"><a href="/events">Edmonton</a></li><li class="parent" data-id="40"><a href="/events">Montreal</a></li><li class="parent" data-id="74"><a href="/events">Ottawa</a></li><li class="parent" data-id="211"><a href="/events">Prairies</a></li><li class="parent" data-id="250"><a href="/events">Quebec</a></li><li class="parent selected" data-id="28"><a href="/events">Toronto</a></li><li class="parent" data-id="39"><a href="/events">Vancouver</a></li><li class="parent" data-id="161"><a href="/events">Windsor</a></li></ul>
# </input></li>
# <li class="but arrow-down right" id="liDate">
# <input id="btnDateRange" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$btnDateRange" style="display:none;" type="submit" value=""/>
# <input id="hdnDateRange" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnDateRange" type="hidden" value="2"/>
# <span data-id="2">By week</span><ul class="links" style="display: none;"><li data-id="1"><a href="/events/ca/toronto/default/0-0-0">By day</a></li><li class="selected" data-id="2"><a href="/events/ca/toronto/default/0-0-0">By week</a></li><li data-id="3"><a href="/events/ca/toronto/default/0-0-0">By month</a></li></ul>
# </li>
# </ul>
# </div>
# <div class="fl col4" id="event-listing">
# <ul class="list" id="items">
# <li><p class="eventDate date"><a href="/events.aspx?ai=28&amp;v=day&amp;mn=9&amp;yr=2020&amp;dy=5"><span>Sat, 05 Sep 2020 /</span></a></p></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-09-05T00:00" itemprop="startDate">2020-09-05T00:00</time></span><a href="/events/1396872"><img height="76" src="/images/events/flyer/2020/9/ca-0905-1396872-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1396872" itemprop="url" title="Event details of Electric Island Labour Day 1">Electric Island Labour Day 1</a> <span>at <a href="/club.aspx?id=182456">Ontario Place West Island</a></span></h1><div class="grey event-lineup">T.B.A</div><p class="attending"><span>7</span> Attending</p></div></article></li>
# </ul>
# </div>
# <div class="fl col2" style="padding-top: 88px;">
# <div class="pr8 sticky">
# <section id="calendar">
# <div class="h-align">
# <h1 class="heading">Calendar</h1>
# </div>
# <div id="calendar-inner">
# <select id="ddlCalendarMonth" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarMonth" style="width:104px;">
# <option value="12">December</option>
# <option value="11">November</option>
# <option value="10">October</option>
# <option value="9">September</option>
# <option selected="selected" value="8">August</option>
# <option value="7">July</option>
# <option value="6">June</option>
# <option value="5">May</option>
# <option value="4">April</option>
# <option value="3">March</option>
# <option value="2">February</option>
# <option value="1">January</option>
# </select>
# <select id="ddlCalendarYear" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarYear">
# <option value="2022">2022</option>
# <option value="2021">2021</option>
# <option selected="selected" value="2020">2020</option>
# <option value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# </select>
# <select id="ddlCalendarType" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarType" style="width:104px;">
# <option value="day">By day</option>
# <option selected="selected" value="week">By week</option>
# <option value="month">By month</option>
# </select>
# <input id="hfCalendarDayOfWeek" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$hfCalendarDayOfWeek" type="hidden" value="31"/>
# <table><tr><th>Sun</th><th>Mon</th><th>Tue</th><th>Wed</th><th>Thu</th><th>Fri</th><th>Sat</th></tr><tr><td><a class="day-off" href="/events/ca/toronto/week/2020-07-26">26</a></td><td><a class="day-off" href="/events/ca/toronto/week/2020-07-27">27</a></td><td><a class="day-off" href="/events/ca/toronto/week/2020-07-28">28</a></td><td><a class="day-off" href="/events/ca/toronto/week/2020-07-29">29</a></td><td><a class="day-off" href="/events/ca/toronto/week/2020-07-30">30</a></td><td><a class="day-off" href="/events/ca/toronto/week/2020-07-31">31</a></td><td><a href="/events/ca/toronto/week/2020-08-01">1</a></td></tr><tr><td><a href="/events/ca/toronto/week/2020-08-02">2</a></td><td><a href="/events/ca/toronto/week/2020-08-03">3</a></td><td><a href="/events/ca/toronto/week/2020-08-04">4</a></td><td><a href="/events/ca/toronto/week/2020-08-05">5</a></td><td><a href="/events/ca/toronto/week/2020-08-06">6</a></td><td><a href="/events/ca/toronto/week/2020-08-07">7</a></td><td><a href="/events/ca/toronto/week/2020-08-08">8</a></td></tr><tr><td><a href="/events/ca/toronto/week/2020-08-09">9</a></td><td><a href="/events/ca/toronto/week/2020-08-10">10</a></td><td><a href="/events/ca/toronto/week/2020-08-11">11</a></td><td><a href="/events/ca/toronto/week/2020-08-12">12</a></td><td><a href="/events/ca/toronto/week/2020-08-13">13</a></td><td><a href="/events/ca/toronto/week/2020-08-14">14</a></td><td><a href="/events/ca/toronto/week/2020-08-15">15</a></td></tr><tr><td><a href="/events/ca/toronto/week/2020-08-16">16</a></td><td><a href="/events/ca/toronto/week/2020-08-17">17</a></td><td><a href="/events/ca/toronto/week/2020-08-18">18</a></td><td><a href="/events/ca/toronto/week/2020-08-19">19</a></td><td><a href="/events/ca/toronto/week/2020-08-20">20</a></td><td><a href="/events/ca/toronto/week/2020-08-21">21</a></td><td><a href="/events/ca/toronto/week/2020-08-22">22</a></td></tr><tr><td><a href="/events/ca/toronto/week/2020-08-23">23</a></td><td><a href="/events/ca/toronto/week/2020-08-24">24</a></td><td><a href="/events/ca/toronto/week/2020-08-25">25</a></td><td><a href="/events/ca/toronto/week/2020-08-26">26</a></td><td><a href="/events/ca/toronto/week/2020-08-27">27</a></td><td><a href="/events/ca/toronto/week/2020-08-28">28</a></td><td><a href="/events/ca/toronto/week/2020-08-29">29</a></td></tr><tr><td><a href="/events/ca/toronto/week/2020-08-30">30</a></td><td><span class="day-current">31</span></td><td><a class="day-off" href="/events/ca/toronto/week/2020-09-01">1</a></td><td><a class="day-off" href="/events/ca/toronto/week/2020-09-02">2</a></td><td><a class="day-off" href="/events/ca/toronto/week/2020-09-03">3</a></td><td><a class="day-off" href="/events/ca/toronto/week/2020-09-04">4</a></td><td><a class="day-off" href="/events/ca/toronto/week/2020-09-05">5</a></td></tr></table>
# </div>
# <script type="text/javascript">
# 		$("#ddlCalendarMonth, #ddlCalendarYear, #ddlCalendarType").change(function () {
#             var aSearch = location.search.indexOf("&") > 0
#                 ? location.search.split('&')
#                 : "";
#
# 			var sQueryString;
#
#             var month = $('#ddlCalendarMonth').val().length === 2
#                 ? $('#ddlCalendarMonth').val()
#                 : "0" + $('#ddlCalendarMonth').val();
#
#             var day = $('#hfCalendarDayOfWeek').val().length === 2
#                 ? $('#hfCalendarDayOfWeek').val()
#                 : "0" + $('#hfCalendarDayOfWeek').val();
#
#             var area = $('#liArea span').text().toLowerCase() === 'all'
#                 ? ""
#                 : $('#liArea span').text();
#
#             var country = area === ''
#                 ? $('#country-name').val()
#                 : $('#liCountry span').text()
#
# 			sQueryString = "/events/"
#                 + country.replace(/[^A-Z0-9]/ig, '').toLowerCase() + "/"
#                 + area.replace(/[^A-Z0-9À-ž]/ig, '').toLowerCase().normalize("NFD").replace(/[\u0300-\u036f]/g, "") + "/"
#                 + $('#ddlCalendarType').val() + "/"
# 				+ $('#ddlCalendarYear').val() + "-"
#                 + month + "-"
# 				+ day;
#
# 			location.href = sQueryString;
# 		});
# 	</script>
# </section>
# <div class="banner">
# <div id="pnlMPU">
# <div class="ad" id="div-gpt-ad-1452773484957-7" style="width: 300px; min-height: 250px; padding-bottom: 10px;"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="fl col2 h-align-toplist">
# <div class="mr8">
# <section class="top-list generic events" id="toplist">
# <h1 class="heading">Top Toronto clubs</h1>
# <ul>
# <li><a ga-event-action="Coda" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=87206">Coda</a> /</li><li><a ga-event-action="The Comfort Zone" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=4665">The Comfort Zone</a> /</li><li><a ga-event-action="Bambi's" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=69282">Bambi's</a> /</li><li><a ga-event-action="500 Keele Warehouse" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=143086">500 Keele Warehouse</a> /</li><li><a ga-event-action="NEST" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=98164">NEST</a> /</li><li><a ga-event-action="The Drake Hotel" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=8062">The Drake Hotel</a> /</li><li><a ga-event-action="Sunnyside Pavilion" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=18553">Sunnyside Pavilion</a> /</li><li><a ga-event-action="99 Sudbury" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=4722">99 Sudbury</a> /</li><li><a ga-event-action="Rebel" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=9575">Rebel</a> /</li><li><a ga-event-action="Mod Club Theatre" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=5159">Mod Club Theatre</a> /</li><li><a ga-event-action="One Loft" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=130597">One Loft</a> /</li><li><a ga-event-action="Li'ly Resto Lounge" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=7842">Li'ly Resto Lounge</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-clubs" ga-on="click" href="/clubs.aspx?ai=28">More Toronto clubs</a></div>
# </section><section class="top-list generic events" id="toplist">
# <h1 class="heading">Top 20 regions</h1>
# <ul>
# <li><a ga-event-action="London" ga-event-category="top-regions" ga-on="click" href="/guide/uk/london">London, UK</a> /</li><li><a ga-event-action="Berlin" ga-event-category="top-regions" ga-on="click" href="/guide/de/berlin">Berlin, DE</a> /</li><li><a ga-event-action="Ibiza" ga-event-category="top-regions" ga-on="click" href="/guide/es/ibiza">Ibiza, ES</a> /</li><li><a ga-event-action="Tokyo" ga-event-category="top-regions" ga-on="click" href="/guide/jp/tokyo">Tokyo, JP</a> /</li><li><a ga-event-action="Amsterdam" ga-event-category="top-regions" ga-on="click" href="/guide/nl/amsterdam">Amsterdam, NL</a> /</li><li><a ga-event-action="Prague" ga-event-category="top-regions" ga-on="click" href="/guide/cz/prague">Prague, CZ</a> /</li><li><a ga-event-action="All" ga-event-category="top-regions" ga-on="click" href="/guide/streamland">Streamland</a> /</li><li><a ga-event-action="New York" ga-event-category="top-regions" ga-on="click" href="/guide/us/newyork">New York, US</a> /</li><li><a ga-event-action="South + East" ga-event-category="top-regions" ga-on="click" href="/guide/uk/southeast">South + East, UK</a> /</li><li><a ga-event-action="Paris" ga-event-category="top-regions" ga-on="click" href="/guide/fr/paris">Paris, FR</a> /</li><li><a ga-event-action="Barcelona" ga-event-category="top-regions" ga-on="click" href="/guide/es/barcelona">Barcelona, ES</a> /</li><li><a ga-event-action="Manchester" ga-event-category="top-regions" ga-on="click" href="/guide/uk/manchester">Manchester, UK</a> /</li><li><a ga-event-action="Midlands" ga-event-category="top-regions" ga-on="click" href="/guide/uk/midlands">Midlands, UK</a> /</li><li><a ga-event-action="Other regions" ga-event-category="top-regions" ga-on="click" href="/guide/nl/otherregions">Other regions, NL</a> /</li><li><a ga-event-action="Glasgow" ga-event-category="top-regions" ga-on="click" href="/guide/uk/glasgow">Glasgow, UK</a> /</li><li><a ga-event-action="Chengdu" ga-event-category="top-regions" ga-on="click" href="/guide/cn/chengdu">Chengdu, CN</a> /</li><li><a ga-event-action="North" ga-event-category="top-regions" ga-on="click" href="/guide/uk/north">North, UK</a> /</li><li><a ga-event-action="Liverpool" ga-event-category="top-regions" ga-on="click" href="/guide/uk/liverpool">Liverpool, UK</a> /</li><li><a ga-event-action="Shenzhen" ga-event-category="top-regions" ga-on="click" href="/guide/cn/shenzhen">Shenzhen, CN</a> /</li><li><a ga-event-action="Budapest" ga-event-category="top-regions" ga-on="click" href="/guide/hu/budapest">Budapest, HU</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-regions" ga-on="click" href="/events.aspx?show=all">More regions</a></div>
# </section><div id="pnlSkyscraper">
# <div class="ad mobile-off" id="div-gpt-ad-1452773484957-12" style="width: 160px; height: 600px;"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="page-items content sub clearfix">
# <ul>
# <li class="but arrow-left left" id="liPrevious2">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/ca/toronto/week/2020-08-23">Previous </a>
# </li><li class="but arrow-right right" id="liNext2">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/ca/toronto/week/2020-09-06">Next </a>
# </li>
# </ul>
# </div>
# <div class="banner clearfix">
# <div id="pnlECTOSlot2" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-1"></div>
# </div>
# </div>
# <br/>
# <span>01 /</span>
# </li>
# <li class="alt">
# <section class="content" id="popular-news">
# <h1 class="heading listing-heading">Most popular news</h1>
# <div class="but heading-more mobile-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# <div class="strip small slide" data-type="news" id="news-listing">
# <ul class="list">
# <li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 28 Aug 2020</p>
# <a href="/news/72186">
# <img class="thumb" src="/images/news/2020/caprices-switzerland-sven-vath.jpg">
# </img></a>
# <p class="comments light">
# <a href="/news/72186/?comments=1">Post a comment</a>
# </p><a href="/news/72186">
# <h1>Coronavirus latest: Swiss festival Caprices confirms 2020 lineup, Glasgow's Riverside joins festivals announcing 2021 lineup</h1>
# </a>
# <p class="copy">Everything we know about how COVID-19 (the disease caused by the novel coronavirus) is affecting the electronic music scene.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 24 Aug 2020</p>
# <a href="/news/73334">
# <img class="thumb" src="/images/news/2020/ilegal-rave-england-rise-2020.jpg">
# </img></a>
# <p class="comments light">
# <a href="/news/73334/?comments=1">Post a comment</a>
# </p><a href="/news/73334">
# <h1>Illegal rave organisers in England face fines of up to £10,000</h1>
# </a>
# <p class="copy">The new rules, which apply to groups of more than 30 people, come into effect this Friday, August 28th.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 24 Aug 2020</p>
# <a href="/news/73335">
# <img class="thumb" src="/images/news/2020/thomas-restobar-lima.png"/>
# </a>
# <p class="comments light">
# <a href="/news/73335/?comments=1">Post a comment</a>
# </p><a href="/news/73335">
# <h1>Police raid at Lima nightclub leaves at least 13 dead</h1>
# </a>
# <p class="copy">Partygoers trying to flee Thomas Restobar Club, which was in breach of COVID-19 regulations, were crushed to death or asphyxiated.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 25 Aug 2020</p>
# <a href="/news/73341">
# <img class="thumb" src="/images/news/2020/roman-flugel-motd.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73341/?comments=1">Post a comment</a>
# </p><a href="/news/73341">
# <h1>Mix Of The Day: Roman Flügel</h1>
# </a>
# <p class="copy">This Rinse FM session shows Flügel at his most inspired.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 27 Aug 2020</p>
# <a href="/news/73364">
# <img class="thumb" src="/images/news/2020/avalon-emerson-dj-kicks.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73364/?comments=1">Post a comment</a>
# </p><a href="/news/73364">
# <h1>Avalon Emerson mixes 72nd DJ-Kicks</h1>
# </a>
# <p class="copy">The next mix in !K7's series is out on September 18th.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 25 Aug 2020</p>
# <a href="/news/73346">
# <img class="thumb" src="/images/news/2020/blowing-up-the-workshop-mix-series-ends-2020.png"/>
# </a>
# <p class="comments light">
# <a href="/news/73346/?comments=1">Post a comment</a>
# </p><a href="/news/73346">
# <h1>Blowing Up The Workshop mix series bows out after eight years</h1>
# </a>
# <p class="copy">Matthew Kent's beloved outlet winds down with seven new mixes from CCL, Akash, Dr. Banana and more.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 27 Aug 2020</p>
# <a href="/news/73370">
# <img class="thumb" src="/images/news/2020/france-covid-5000-cap.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73370/?comments=1">Post a comment</a>
# </p><a href="/news/73370">
# <h1>France eases rules on social distancing at events with under 5,000 people</h1>
# </a>
# <p class="copy">The move, announced by prime minister Jean Castex, has been made in an attempt to kick-start France's economy.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 25 Aug 2020</p>
# <a href="/news/73350">
# <img class="thumb" src="/images/news/2020/tom-rellen-rip.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73350/?comments=1">Post a comment</a>
# </p><a href="/news/73350">
# <h1>Tom Relleen, Tomaga member and key London experimentalist, has died</h1>
# </a>
# <p class="copy">Relleen was also a founding member of Phonica Records, a booking agent with the Julie Tippex agency and one-half of The Oscillation and Autotelia.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 26 Aug 2020</p>
# <a href="/news/73356">
# <img class="thumb" src="/images/news/2020/anz-hessle-audio-ep-photo-by-joseph-burton.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73356/?comments=1">Post a comment</a>
# </p><a href="/news/73356">
# <h1>Anz debuts on Hessle Audio with new EP, Loos In Twos (NRG)</h1>
# </a>
# <p class="copy">The three-track release is out September 4th.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 27 Aug 2020</p>
# <a href="/news/73372">
# <img class="thumb" src="/images/news/2020/1591028202_000-1sm7kg.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73372/?comments=1">Post a comment</a>
# </p><a href="/news/73372">
# <h1>Berlin's senate seeks open-air spaces where local clubs can host socially distanced parties</h1>
# </a>
# <p class="copy">District mayors have been asked to scour their areas for parks, streets and sports halls that could be transformed into legal outdoor rave venues.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 27 Aug 2020</p>
# <a href="/news/73360">
# <img class="thumb" src="/images/news/2020/jeff-mils-new-albums-axis-terrence-dixon-tadeo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73360/?comments=1">Post a comment</a>
# </p><a href="/news/73360">
# <h1>Axis Records releases new albums from Jeff Mills, Terrence Dixon and Tadeo</h1>
# </a>
# <p class="copy">All three records are available now.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 28 Aug 2020</p>
# <a href="/news/73384">
# <img class="thumb" src="/images/news/2020/faithless-new-album-all-blessed-bmg-sister-bliss-photo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73384/?comments=1">Post a comment</a>
# </p><a href="/news/73384">
# <h1>Faithless return with All Blessed, their first new album in a decade</h1>
# </a>
# <p class="copy">Out October 23rd, the 12-track LP features GAIKA, Jazzie B OBE, Caleb Femi and more.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 27 Aug 2020</p>
# <a href="/news/73368">
# <img class="thumb" src="/images/news/2020/carrot-green-dekmantel-mix-of-the-day.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73368/?comments=1">Post a comment</a>
# </p><a href="/news/73368">
# <h1>Mix Of The Day: Carrot Green</h1>
# </a>
# <p class="copy">The Brazilian favourite in the mix for Dekmantel.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 26 Aug 2020</p>
# <a href="/news/73366">
# <img class="thumb" src="/images/news/2020/bussey-building-culture-recovery-grant.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73366/?comments=1">Post a comment</a>
# </p><a href="/news/73366">
# <h1>Corsica Studios, Phonox among 135 venues receiving support from the UK Culture Recovery Fund</h1>
# </a>
# <p class="copy">Other venues receiving emergency grants include Manchester's Soup Kitchen and Peckham's CLF Art Cafe, site of the Bussey Building and Rye Wax.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 26 Aug 2020</p>
# <a href="/news/73349">
# <img class="thumb" src="/images/news/2020/jordan-gcz-motd.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73349/?comments=1">Post a comment</a>
# </p><a href="/news/73349">
# <h1>Mix Of The Day: Jordan GCZ</h1>
# </a>
# <p class="copy">100 per cent unreleased originals from the Juju &amp; Jordash man, including collaborations with Move D and Terrence Dixon.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 24 Aug 2020</p>
# <a href="/news/73290">
# <img class="thumb" src="/images/news/2020/objectblue-tsvi-new-ep.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73290/?comments=1">Post a comment</a>
# </p><a href="/news/73290">
# <h1>object blue and TSVI to release collaborative EP, Hyperaesthesia</h1>
# </a>
# <p class="copy">Out on Nervous Horizons next month, the 12-inch includes a remix by Loraine James.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 28 Aug 2020</p>
# <a href="/news/73378">
# <img class="thumb" src="/images/news/2020/dj-ez-bbc-radio-1.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73378/?comments=1">Post a comment</a>
# </p><a href="/news/73378">
# <h1>BBC Radio 1 reveals latest residents, DJ EZ, Disclosure, Joy Orbison and Amelie Lens</h1>
# </a>
# <p class="copy">SHERELLE, Saoirse, Teki Latex and Eris Drew &amp; Octo Octa will also return.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 25 Aug 2020</p>
# <a href="/news/73336">
# <img class="thumb" src="/images/news/2020/dial-xdb-album.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73336/?comments=1">Post a comment</a>
# </p><a href="/news/73336">
# <h1>XDB reveals debut album, Inspiron, on Dial</h1>
# </a>
# <p class="copy">The nine-track LP is out October 23rd.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 27 Aug 2020</p>
# <a href="/news/73375">
# <img class="thumb" src="/images/news/2020/toro-y-moi-acemo-ep.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73375/?comments=1">Post a comment</a>
# </p><a href="/news/73375">
# <h1>Toro Y Moi &amp; AceMo release collaborative EP</h1>
# </a>
# <p class="copy">C'mon Les' Go is out now on AceMo's new label, Sonic Messengers.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 24 Aug 2020</p>
# <a href="/news/73339">
# <img class="thumb" src="/images/news/2020/william-basinski-lamentations.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73339/?comments=1">Post a comment</a>
# </p><a href="/news/73339">
# <h1>William Basinski announces new album, Lamentations, made with archival material going back 40 years</h1>
# </a>
# <p class="copy">The LP is out via Temporary Residence Limited in November.</p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# </section>
# <span>02 /</span>
# </li>
# </ul>
# </main>
# </form>
# <footer class="clearfix"><ul class="content-list">
# <li>
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col2-3">
# <ul class="pb32">
# <li id="logo-footer"><a href="/">RA</a></li>
# <li class="f12 grey pt16">Copyright © 2020 Resident Advisor Ltd.</li>
# <li class="f12 grey">All rights reserved.</li>
# <li class="f12 grey"><a href="/privacy">Privacy</a> &amp; <a href="/terms">Terms</a></li>
# <li class="f12 grey"><a href="/cookiepolicy">Cookie Policy</a></li>
# </ul>
# </div>
# <div class="fl col4-5 pt60">
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Resident Advisor /</li> <li><a ga-event-action="about" ga-event-category="homefooter" ga-on="click" href="/about">About</a></li>
# <li><a ga-event-action="advertise" ga-event-category="homefooter" ga-on="click" href="/about/advertising">Advertise</a></li>
# <li><a ga-event-action="jobs" ga-event-category="homefooter" ga-on="click" href="https://www.doorsopen.co/company/12/resident-advisor/#utm_source=RA&amp;utm_medium=footer-link">Jobs</a></li>
# <li><a ga-event-action="raevents" ga-event-category="homefooter" ga-on="click" href="/features/3214">24/7</a></li>
# <li><a ga-event-action="store" ga-event-category="homefooter" ga-on="click" href="https://store.ra.co">RA Store</a></li>
# <li><br/></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">RA Tickets /</li>
# <li><a ga-event-action="mytickets" ga-event-category="homefooter" ga-on="click" href="/shop/history">My Tickets</a></li>
# <li><a ga-event-action="ticketfaq" ga-event-category="homefooter" ga-on="click" href="/shop/faq">Ticketing FAQ</a></li>
# <li><a ga-event-action="resale" ga-event-category="homefooter" ga-on="click" href="/tickets/resale">Resale</a></li>
# <li><a ga-event-action="selltickets" ga-event-category="homefooter" ga-on="click" href="/tickets">Sell tickets on RA</a></li>
# <li><div class="myra but" style="width: 152px; margin-top: 50px;"><a class="submit-event" ga-event-action="submitevent" ga-event-category="homefooter" ga-on="click" href="/submit-event.aspx">Submit event</a></div></li>
# <li><br/></li>
# </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Apps /</li> <li><a ga-event-action="raguide" ga-event-category="homefooter" ga-on="click" href="/ra-guide">RA Guide</a></li>
# <li><a ga-event-action="ticketscanner" ga-event-category="homefooter" ga-on="click" href="/tickets/scanner">RA Ticket Scanner</a></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Elsewhere /</li>
# <li><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/user/residentadvisor?sub_confirmation=1">Watch on YouTube</a></li>
# <li><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">Follow on Facebook</a></li>
# <li><a ga-event-action="raapplemusic" ga-event-category="homefooter" ga-on="click" href="https://itunes.apple.com/gb/curator/resident-advisor/id996091687">Listen on Apple Music</a></li>
# <li><a ga-event-action="raspotify" ga-event-category="homefooter" ga-on="click" href="https://open.spotify.com/user/residentadvisor">Stream on Spotify</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="nobreak">
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col3">
# <a href="https://jp.residentadvisor.net/"><a href="https://jp.residentadvisor.net/">RA is also available in Japanese. 日本版</a></a>
# </div>
# <ul class="col1p5" id="social">
# <li class="ytb"><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/residentadvisor">RA on YouTube</a></li>
# <li class="fcb"><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">RA on Facebook</a></li>
# <li class="twt"><a ga-event-action="ratwitter" ga-event-category="homefooter" ga-on="click" href="http://www.twitter.com/residentadvisor">RA on Twitter</a></li>
# <li class="ins"><a ga-event-action="rainstagram" ga-event-category="homefooter" ga-on="click" href="http://instagram.com/resident_advisor">RA on Instagram</a></li>
# <li class="snd"><a ga-event-action="rasoundcloud" ga-event-category="homefooter" ga-on="click" href="http://www.soundcloud.com/resident-advisor">RA on Soundcloud</a></li>
# </ul>
# </div>
# </div>
# </li>
# </ul></footer>
# <script type="text/javascript">
#         (function(i, s, o, g, r, a, m) {
#                                         i['GoogleAnalyticsObject'] = r;
#                                         i[r] = i[r] || function() {
#                                             (i[r].q = i[r].q || []).push(arguments)
#                                         }, i[r].l = 1 * new Date();
#                                         a = s.createElement(o), m = s.getElementsByTagName(o)[0];
#                                         a.async = 1;
#                                         a.src = g;
#                                         m.parentNode.insertBefore(a, m)
#                                     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#                                     ga('create', 'UA-313318-1', 'residentadvisor.net'
#                                     );
#                                     ga('require', 'displayfeatures');
#                                     ga('send', 'pageview');
#                                     ga('require', 'eventTracker');
#
#         if (window.location.href.indexOf('.residentadvisor.net') >= 0 && window.location.pathname.indexOf('submit-event') === 0) {
# 	        (function(r, a, v, e, l, i, n) {
# 	            r[l] = r[l] || function() { (r[l].q = r[l].q || []).push(arguments) };
# 	            i = a.createElement(v);
# 	            i.async = i.defer = 1;
# 	            i.src = e;
# 	            a.body.appendChild(i)
# 	        })(window, document, 'script', 'https://cdn.ravelin.net/js/rvn-beta.min.js', 'ravelin');
# 	        ravelin('setApiKey', 'pk_live_Z6F2v32uJEQnwn46SLF7xdojmnOPLfAI');
#             ravelin('setCustomerId', '0');
#             ravelin('setCookieDomain', '.residentadvisor.net');
# 	    }
# 	</script>
# <script>
#         cssVars({})
#     </script>
# </body>
# </html>

# %%
def get_events(soup):
    events = soup.findAll('article', class_="event-item")
    return events

# %%
test_events = get_events(test_soup)
test_event = test_events[0]
test_event.prettify()
# Out:
# '<article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">\n <span style="display:none;">\n  <time datetime="2020-09-05T00:00" itemprop="startDate">\n   2020-09-05T00:00\n  </time>\n </span>\n <a href="/events/1396872">\n  <img height="76" src="/images/events/flyer/2020/9/ca-0905-1396872-list.jpg" width="152"/>\n </a>\n <div class="bbox">\n  <h1 class="event-title" itemprop="summary">\n   <a href="/events/1396872" itemprop="url" title="Event details of Electric Island Labour Day 1">\n    Electric Island Labour Day 1\n   </a>\n   <span>\n    at\n    <a href="/club.aspx?id=182456">\n     Ontario Place West Island\n    </a>\n   </span>\n  </h1>\n  <div class="grey event-lineup">\n   T.B.A\n  </div>\n  <p class="attending">\n   <span>\n    7\n   </span>\n   Attending\n  </p>\n </div>\n</article>'

# %%
def get_title(event):
    title = event.find('h1', class_="event-title").find('a').text
    return title

# %%
test_title = get_title(test_event)
test_title
# Out:
# 'Electric Island Labour Day 1'

# %%
def get_venue(event):
    venue = event.find('h1', class_="event-title").find('span').find('a').text
    return venue

# %%
test_venue = get_venue(test_event)
test_venue
# Out:
# 'Ontario Place West Island'

# %%
def get_attendees(event):
    attendees = int(event.find('p', class_='attending').find('span').text)
    return attendees

# %%
test_attendees = get_attendees(test_event)
test_attendees
# Out:
# 7

# %%
def get_date(soup):
    date = soup.find('p', class_="eventDate").find('a').find('span').text.strip('/').strip()
    return date

# %%
test_date = get_date(test_soup)
test_date
# Out:
# 'Sat, 05 Sep 2020'

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
def next_page(soup):
    next_page_url = soup.find('li', id="liNext2").find('a').attrs['href']
    return next_page_url

# %%
test_next_url = next_page(test_soup)
test_next_url
# Out:
# '/events/ca/toronto/week/2020-09-06'

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
events_list = []
base_url = 'https://www.residentadvisor.net'
extension = '/events'
url= base_url+extension
print(initial_url)
while len(events_list) < 3:
    soup = get_soup(url)
    events = get_events(soup)
    next_extension = next_page(soup)
    url = base_url+next_extension
    if len(events)> 0:
        date = get_date(soup)
        for event in events:
            event_dict = {
                'Event_Name': get_title(event), 
                'Venue': get_venue(event), 
                'Event_Date': date, 
                'Number_of_Attendees': get_attendees(event)
            }
            events_list.append(event_dict)
    else:
        continue

df = pd.DataFrame(events_list)
df
# Out:
# https://www.residentadvisor.net/events
#                                           Event_Name  \
# 0                       Electric Island Labour Day 1
# 1                       Electric Island Labour Day 2
# 2  Disco & House Music Tribute Party with Crystal...
#
#                        Venue        Event_Date  Number_of_Attendees
# 0  Ontario Place West Island  Sat, 05 Sep 2020                    7
# 1  Ontario Place West Island  Sun, 06 Sep 2020                    5
# 2                    Revival  Sun, 06 Sep 2020                    8

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully developed a pipeline to scrape a website for concert event information!
